# %% [markdown]
# ____________
# <center>
#   <h1 style="font-size: 40px; font-weight: bold">SKILLCRAFT TECHNOLOGY INTERNSHIP</h1>
# </center>
#
# ______

# %% [markdown]
# <center>
#   <h1 style="font-size: 30px; font-weight: bold">TASK 2: DATA CLEANING AND EXPLORATORY DATA ANALYSIS (EDA)</h1>
# </center>
#
#
#
# * **Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.**

# %% [markdown]
# **Intern: Aswathy S**
#
# **Track: Data Science**
#
# **Task Code: PRODIGY_DS_02**
# _________

# %% [markdown]
# ___________
# # **LOADING LIBRARIES**
# _______

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ___________
# # **LOADING LIBRARIES**
# _______

# %%
df=pd.read_csv(r'C:\Users\admin\Downloads\Employee.csv')
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
df.shape
# Out:
# (148, 6)

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.dtypes
# Out:
# Company     object
# Age        float64
# Salary     float64
# Place       object
# Country     object
# Gender       int64
# dtype: object

# %%
print("Duplicate values:")
print(df.duplicated().sum())
# Out:
# Duplicate values:
# 4

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (144, 6)

# %%
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df
# Out:
#              Company   Age  Salary     Place Country  Gender
# 0                TCS  20.0     NaN   Chennai   India       0
# 1            Infosys  30.0     NaN    Mumbai   India       0
# 2                TCS  35.0  2300.0  Calcutta   India       0
# 3            Infosys  40.0  3000.0     Delhi   India       0
# 4                TCS  23.0  4000.0    Mumbai   India       0
# ..               ...   ...     ...       ...     ...     ...
# 139  Infosys Pvt Lmt  22.0  8202.0    Mumbai   India       0
# 140              TCS  33.0  9024.0  Calcutta   India       1
# 141          Infosys  44.0  4034.0     Delhi   India       1
# 142              TCS  33.0  5034.0    Mumbai   India       1
# 143          Infosys  22.0  8202.0    Cochin   India       0
#
# [144 rows x 6 columns]

# %%
print("Missing values in each column:\n")
print(df.isnull().sum())
# Out:
# Missing values in each column:
#
# Company     8
# Age        17
# Salary     23
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
# Fill missing values as recommended
df['Company'].fillna(df['Company'].mode()[0], inplace=True)
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
df['Place'].fillna(df['Place'].mode()[0], inplace=True)

# %%
df['Gender'] = df['Gender'].map({0: 'Female', 1: 'Male'})

# %%
print("Missing values in each column:\n")
print(df.isnull().sum())
# Out:
# Missing values in each column:
#
# Company    0
# Age        0
# Salary     0
# Place      0
# Country    0
# Gender     0
# dtype: int64

# %%
#Unique value and length in each column

# %%
unique = df.nunique()
unique
# Out:
# Company     6
# Age        29
# Salary     40
# Place      11
# Country     1
# Gender      2
# dtype: int64

# %%
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', 'Tata Consultancy Services', 'Congnizant',
#        'Infosys Pvt Lmt'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([20., 30., 35., 40., 23., 33., 34., 45., 18., 22., 32., 37., 50.,
#        21., 46., 36., 26., 41., 24., 25., 43., 19., 38., 51., 31., 44.,
#        17.,  0., 54.])

# %%
df['Salary'].unique()
# Out:
# array([5000., 2300., 3000., 4000., 6000., 7000., 8000., 9000., 1089.,
#        1234., 3030., 3045., 3184., 4824., 5835., 7084., 8943., 8345.,
#        9284., 9876., 2034., 7654., 2934., 4034., 5034., 8202., 9024.,
#        4345., 6544., 6543., 3234., 4324., 5435., 5555., 8787., 3454.,
#        5654., 5009., 5098., 3033.])

# %%
df['Place'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Calcutta', 'Delhi', 'Podicherry', 'Cochin',
#        'Noida', 'Hyderabad', 'Bhopal', 'Nagpur', 'Pune'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.rename(columns={'Age': 'Employee Age', 'Salary': 'Employee Salary', }, inplace=True)

# %%
df.replace({'Tata Consultancy Services': 'TCS'}, inplace=True)
df.replace({'Infosys Pvt Lmt': 'Infosys'}, inplace=True)
df.replace({'CTS': 'Cognizant'}, inplace=True)
df.replace({'Congnizant': 'Cognizant'}, inplace=True)
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'Cognizant'], dtype=object)

# %%
# Spelling correction in 'Podicherry'
df.replace({'Podicherry':'Pondicherry'},inplace=True)
df['Place'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Calcutta', 'Delhi', 'Pondicherry', 'Cochin',
#        'Noida', 'Hyderabad', 'Bhopal', 'Nagpur', 'Pune'], dtype=object)

# %%
print(df.columns.tolist())
# Out:
# ['Company', 'Employee Age', 'Employee Salary', 'Place', 'Country', 'Gender']

# %%
#treat 'Age' column
# replace the value'0' in Age as 'NaN'
# For the 'Age' column, fillna by mean value

# %%
df[df['Employee Age'] == 0]
# Out:
#        Company  Employee Age  Employee Salary        Place Country  Gender
# 87     Infosys           0.0           3030.0     Calcutta   India  Female
# 91         TCS           0.0           3045.0        Delhi   India  Female
# 100  Cognizant           0.0           2034.0  Pondicherry   India  Female
# 106        TCS           0.0           9024.0      Chennai   India    Male
# 110    Infosys           0.0           3234.0       Mumbai   India  Female
# 120  Cognizant           0.0           1234.0     Calcutta   India  Female

# %%
df['Employee Age'] = df['Employee Age'].replace(0, np.nan)

# %%
missing_values = df.isna().sum()
missing_values
# Out:
# Company            0
# Employee Age       6
# Employee Salary    0
# Place              0
# Country            0
# Gender             0
# dtype: int64

# %%
mean_age = df['Employee Age'].mean()
df['Employee Age'].fillna(mean_age, inplace=True)

# %%
missing_values = df.isna().sum()
missing_values
# Out:
# Company            0
# Employee Age       0
# Employee Salary    0
# Place              0
# Country            0
# Gender             0
# dtype: int64

# %%
# Boxplot for Age
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Employee Age'], color='skyblue')
plt.title('Boxplot of Age')
plt.xlabel('Age')
plt.show()

# %%
# Boxplot for Salary
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Employee Salary'], color='lightgreen')
plt.title('Boxplot of Salary')
plt.show()

# %%
df.shape
# Out:
# (144, 6)

# %% [markdown]
# ___________________
# # 1. Basic Variable Relationships
# _________________
# ## a. Numerical vs Numerical
# ### Explore correlation between Age and Salary:
# _________________________

# %%
# Scatter plot
plt.scatter(df['Employee Age'], df['Employee Salary'], color ='r')
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.title('Employee Age v/s Employee Salary')   
plt.show()

# %%
# Correlation value
print("Correlation:", df['Employee Age'].corr(df['Employee Salary']))
# Out:
# Correlation: -0.014983181246339485

# %% [markdown]
# ### b. Categorical vs Numerical
# ### Compare average salaries by Company or Gender:

# %%
custom_palette = {
    'TCS': '#66c2a5',         
    'Infosys': '#fc8d62',     
    'Cognizant': '#8da0cb'    
}

# Create the boxplot
sns.boxplot(x='Company', y='Employee Salary', data=df, palette=custom_palette)
plt.title('Salary Distribution by Company')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
gender_palette = {'Male': 'skyblue', 'Female': 'lightpink'}

# Barplot: Average Salary by Gender
sns.barplot(x='Gender', y='Employee Salary', data=df, palette=gender_palette)
plt.title('Average Salary by Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# _______________
# # 2. Check for Patterns or Trends
# ____________
# ## a. Salary by Location
# ____________

# %%
# Average Salary by Place
avg_salary_by_place = df.groupby('Place')['Employee Salary'].mean().sort_values(ascending=False)
avg_salary_by_place.plot(kind='bar', figsize=(10, 4), title='Average Salary by Place', color='orange')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# __________
# ## b. Age Group Analysis
# ____________

# %%
# Define bins and labels
bins = [18, 25, 35, 45, 60]
labels = ['18–25', '26–35', '36–45', '46–60']

# Create Age Group column
df['Age Group'] = pd.cut(df['Employee Age'], bins=bins, labels=labels)

# Define custom palette
age_palette = {
    '18–25': '#FF9999',   
    '26–35': '#66B2FF',   
    '36–45': '#99FF99',   
    '46–60': '#FFCC99'    
}

# Plot average salary by age group
plt.figure(figsize=(8, 5))
sns.barplot(
    x='Age Group', 
    y='Employee Salary', 
    data=df, 
    estimator='mean', 
    ci=None, 
    palette=age_palette
)
plt.title('Average Salary by Age Group')
plt.ylabel('Average Salary')
plt.xlabel('Age Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# ___________
# # 3. Heatmap of Correlations
# _____________

# %%
numeric_cols = df.select_dtypes(include='number')

# Heatmap
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# _____________
# # 1. Pie Charts for Categorical Features
# __________

# %%
#Pie charts work well to understand proportions in smaller category sets (like Gender, Country):
categorical_cols = ['Company', 'Place', 'Country', 'Gender']

for col in categorical_cols:
    plt.figure(figsize=(6, 6))
    df[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
    plt.title(f'Distribution of {col}', fontsize=14)
    plt.ylabel('')  
    plt.show()

# %% [markdown]
# _____________
# # 2. Grouped Count Plots: Gender Split by Company
# __________

# %%
#This shows how many males/females are in each company:
plt.figure(figsize=(8, 5))
sns.countplot(x='Company', hue='Gender', data=df, palette='Set2')
plt.title('Gender Distribution Across Companies', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# -------------------------------------------------------------END------------------------------------------------------------------------
